# %% [markdown]
# 数据划分

# %%
# !python split.py

# %% [markdown]
# 数据集处理为npy格式(joint模态)

# %%
# !python gen_joint.py
# Out:
# 100%|██████████████████████████████████████| 6307/6307 [00:41<00:00, 152.05it/s]
# pad the null frames with the previous frames
#  42%|███████████████▌                     | 7021/16724 [00:44<00:57, 168.29it/s]2724  has no skeleton
# 100%|██████████████████████████████████████| 6599/6599 [00:45<00:00, 146.07it/s]
# pad the null frames with the previous frames
# 100%|██████████████████████████████████████| 6307/6307 [00:06<00:00, 901.73it/s]
# sub the center joint #1 (spine joint in ntu and neck joint in kinetics)
# 100%|█████████████████████████████████████| 6307/6307 [00:01<00:00, 6027.01it/s]
# parallel the bone between hip(jpt 11)and spine(jpt 5) of the first person to the z axis
#   0%|▏                                        | 30/6307 [00:00<02:03, 50.66it/s]5222  has no skeleton
# 100%|█████████████████████████████████████| 6599/6599 [00:06<00:00, 1024.90it/s]
# sub the center joint #1 (spine joint in ntu and neck joint in kinetics)
# 100%|█████████████████████████████████████| 6599/6599 [00:01<00:00, 5308.00it/s]
# parallel the bone between hip(jpt 11)and spine(jpt 5) of the first person to the z axis
# 100%|████████████████████████████████████| 16724/16724 [01:48<00:00, 153.96it/s]
# pad the null frames with the previous frames
# 100%|████████████████████████████████████| 16432/16432 [01:48<00:00, 151.09it/s]
# pad the null frames with the previous frames
#  44%|█████████████████▎                     | 2922/6599 [01:11<01:17, 47.23it/s]14690  has no skeleton
#  54%|████████████████████▉                  | 3390/6307 [01:15<01:53, 25.63it/s]13619  has no skeleton
# 100%|████████████████████████████████████| 16724/16724 [00:17<00:00, 930.87it/s]
# sub the center joint #1 (spine joint in ntu and neck joint in kinetics)
# 100%|████████████████████████████████████| 16432/16432 [00:19<00:00, 839.86it/s]
# sub the center joint #1 (spine joint in ntu and neck joint in kinetics)
# 100%|███████████████████████████████████| 16724/16724 [00:03<00:00, 4797.95it/s]
# parallel the bone between hip(jpt 11)and spine(jpt 5) of the first person to the z axis
# 100%|███████████████████████████████████| 16432/16432 [00:03<00:00, 4335.36it/s]
# parallel the bone between hip(jpt 11)and spine(jpt 5) of the first person to the z axis
# 100%|███████████████████████████████████████| 6307/6307 [02:20<00:00, 44.90it/s]
# 100%|███████████████████████████████████████| 6599/6599 [02:42<00:00, 40.61it/s]
# 100%|█████████████████████████████████████| 16432/16432 [06:14<00:00, 43.86it/s]
# 100%|█████████████████████████████████████| 16724/16724 [06:28<00:00, 43.01it/s]

# %% [markdown]
# 数据集处理为出bone模态

# %%
# !python gen_bone.py
# Out:
# v2 test
# v2 train
# v1 test
# v1 train
# 100%|███████████████████████████████████████████| 18/18 [00:11<00:00,  1.61it/s]
# 100%|███████████████████████████████████████████| 18/18 [00:11<00:00,  1.52it/s]
# 100%|███████████████████████████████████████████| 18/18 [01:10<00:00,  3.93s/it]
# 100%|███████████████████████████████████████████| 18/18 [01:15<00:00,  4.17s/it]

# %% [markdown]
# bone模态与joint模态合并

# %%
# !python merge_joint_bone.py
# Out:
# v2 train
# v2 test
# v1 train
# v1 test

# %% [markdown]
# 数据集处理出motion模态数据

# %%
# !python gen_motion.py
# Out:
# v1 train bone
# 100%|█████████████████████████████████████████| 299/299 [07:31<00:00,  1.51s/it]
# v1 train joint
# 100%|█████████████████████████████████████████| 299/299 [08:18<00:00,  1.67s/it]
# v1 test bone
# 100%|█████████████████████████████████████████| 299/299 [07:23<00:00,  1.48s/it]
# v1 test joint
# 100%|█████████████████████████████████████████| 299/299 [01:51<00:00,  2.69it/s]
# v2 train bone
# 100%|█████████████████████████████████████████| 299/299 [16:20<00:00,  3.28s/it]
# v2 train joint
# 100%|█████████████████████████████████████████| 299/299 [07:52<00:00,  1.58s/it]
# v2 test bone
# 100%|█████████████████████████████████████████| 299/299 [00:13<00:00, 22.44it/s]
# v2 test joint
# 100%|█████████████████████████████████████████| 299/299 [00:20<00:00, 14.82it/s]

# %% [markdown]
# 测试生成数据

# %%
import pickle
import numpy as np

path = 'data/v1/train_label.pkl'
with open(path, 'rb') as f:
    data = pickle.load(f)
    print(data[0][0])
    print(data[1][0])


path = 'data/v1/train_data_joint.npy'
x = np.load(path)
print(x.shape)

path = 'data/v1/train_data_bone.npy'
x = np.load(path)
print(x.shape)

path = 'data/v1/train_data_joint_bone.npy'
x = np.load(path)
print(x.shape)
# Out:
# data/v1/train/P000S00G10B10H10UC022000LC021000A000R0_08241716.txt
# 0
# (16724, 3, 300, 17, 2)
# (16724, 3, 300, 17, 2)
# (16724, 6, 300, 17, 2)
