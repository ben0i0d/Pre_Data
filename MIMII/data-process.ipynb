# %%
# !pip install matplotlib audioflux
# Out:
# Looking in indexes: https://mirrors.bfsu.edu.cn/pypi/web/simple
# ...

# %%
# !python gen_mfcc.py
# Out:
# processing -6dB fan
# ...
# 100%|██████████████████████████████████████| 1015/1015 [00:07<00:00, 134.99it/s]
# processing -6dB pump
# ...
# 100%|██████████████████████████████████████| 1036/1036 [00:07<00:00, 132.48it/s]
# processing -6dB slider
# ...
# 100%|████████████████████████████████████████| 534/534 [00:03<00:00, 145.01it/s]
# processing -6dB valve
# ...
# 100%|████████████████████████████████████████| 992/992 [00:07<00:00, 133.68it/s]
# processing 0dB fan
# ...
# 100%|██████████████████████████████████████| 1015/1015 [00:08<00:00, 120.50it/s]
# processing 0dB pump
# ...
# 100%|██████████████████████████████████████| 1036/1036 [00:07<00:00, 134.10it/s]
# processing 0dB slider
# ...
# 100%|████████████████████████████████████████| 534/534 [00:03<00:00, 144.76it/s]
# processing 0dB valve
# ...
# 100%|████████████████████████████████████████| 992/992 [00:07<00:00, 131.94it/s]
# processing 6dB fan
# ...
# 100%|██████████████████████████████████████| 1015/1015 [00:07<00:00, 137.60it/s]
# processing 6dB pump
# ...

# %% [markdown]
# 数据分布不均匀

# %%
import pickle

with open('data/data.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
u = v =0 

for i in data[0]:
    if i[2] == 0:
        u+=1
    else:
        v+=1

print(u,v)
# Out:
# 14719 3300

# %%
data[0][0]
# Out:
# [array([[-2.19014893e+01, -2.23982582e+01, -2.20333443e+01, ...,
#          -2.26226368e+01, -2.24891338e+01, -2.30250397e+01],
#         [ 1.35211067e+01,  1.38043289e+01,  1.37606325e+01, ...,
#           1.30134554e+01,  1.41551027e+01,  1.40228310e+01],
#         [ 1.66905379e+00,  1.89504945e+00,  1.71616757e+00, ...,
#           1.34916294e+00,  1.42652953e+00,  1.57365561e+00],
#         ...,
#         [ 1.07126677e+00,  9.81605589e-01,  7.08486497e-01, ...,
#           1.02637148e+00, -1.88029051e-01,  5.52031934e-01],
#         [ 4.70458627e-01,  9.98682261e-01,  2.52874970e-01, ...,
#          -3.94632727e-01, -1.21640414e-03,  1.31808534e-01],
#         [ 6.73465908e-01, -2.44200796e-01,  5.56269944e-01, ...,
#           7.18667924e-01,  6.16010487e-01,  1.98193654e-01]],
#        shape=(13, 153), dtype=float32),
#  0,
#  1]
