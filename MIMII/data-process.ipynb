# %%
# !pip install matplotlib audioflux
# Out:
# Looking in indexes: https://mirrors.bfsu.edu.cn/pypi/web/simple
# ...
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/01/75/6c7ce560e95714a10fcbb3367d1304975a1a3e620f72af28921b796403f3/matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# ...
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/be/a6/f54fdbaaa8c5600afd8a47e4185178c688e8af55f5c455aa8f777aab8c36/audioflux-0.1.9-py3-none-any.whl (70.8 MB)
# ...
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/85/fc/7fa5d17daf77306840a4e84668a48ddff09e6bc09ba4e37e85ffc8e4faa3/contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
# ...
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...

# %%
# !python gen_mfcc.py
# Out:
# processing -6dB fan
# ...
# 100%|███████████████████████████████████████| 1015/1015 [00:17<00:00, 59.68it/s]
# processing -6dB pump
# ...
# 100%|███████████████████████████████████████| 1036/1036 [00:17<00:00, 57.74it/s]
# processing -6dB slider
# ...
# 100%|█████████████████████████████████████████| 534/534 [00:08<00:00, 63.21it/s]
# processing -6dB valve
# ...
# 100%|█████████████████████████████████████████| 992/992 [00:16<00:00, 60.06it/s]
# processing 0dB fan
# ...
# 100%|███████████████████████████████████████| 1015/1015 [00:15<00:00, 66.94it/s]
# processing 0dB pump
# ...
# 100%|███████████████████████████████████████| 1036/1036 [00:16<00:00, 61.52it/s]
# processing 0dB slider
# ...
# 100%|█████████████████████████████████████████| 534/534 [00:08<00:00, 60.99it/s]
# processing 0dB valve
# ...
# 100%|█████████████████████████████████████████| 992/992 [00:17<00:00, 57.69it/s]
# processing 6dB fan
# ...
# 100%|███████████████████████████████████████| 1015/1015 [00:17<00:00, 58.68it/s]
# processing 6dB pump
# ...

# %%
import pickle

with open('data/data.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
len(data)
# Out:
# 3

# %%
data[0][0][0].shape
# Out:
# (13, 153)
