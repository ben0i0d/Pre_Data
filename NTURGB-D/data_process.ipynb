# %%
# !python gendata.py
# Out:
# ...
# 100%|████████████████████████████████████| 40091/40091 [04:32<00:00, 147.04it/s]

# %% [markdown]
# 测试

# %%
import pickle
import numpy as np

path = 'data/xsub/train_label.pkl'
with open(path, 'rb') as f:
    data = pickle.load(f)
    print(data[0][0])
    print(data[1][0])

path = 'data/xsub/train_data.npy'
x = np.load(path)
print(x.shape)
# Out:
# S001C003P004R002A038.skeleton
# 37
# (40091, 3, 300, 25, 2)
